# %%
# %pip install transformers datasets torch scikit-learn pandas
# Out:
# Collecting transformers
#   Using cached transformers-4.57.3-py3-none-any.whl.metadata (43 kB)
# Collecting datasets
#   Using cached datasets-4.4.1-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: torch in d:\srijan\jupyter-analysis\finance\.venv\lib\site-packages (2.9.1)
# Requirement already satisfied: scikit-learn in d:\srijan\jupyter-analysis\finance\.venv\lib\site-packages (1.8.0)
# Requirement already satisfied: pandas in d:\srijan\jupyter-analysis\finance\.venv\lib\site-packages (2.3.3)
# Requirement already satisfied: filelock in d:\srijan\jupyter-analysis\finance\.venv\lib\site-packages (from transformers) (3.20.1)
# Collecting huggingface-hub<1.0,>=0.34.0 (from transformers)
#   Using cached huggingface_hub-0.36.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: numpy>=1.17 in d:\srijan\jupyter-analysis\finance\.venv\lib\site-packages (from transformers) (2.3.5)
# Requirement already satisfied: packaging>=20.0 in d:\srijan\jupyter-analysis\finance\.venv\lib\site-packages (from transformers) (25.0)
# Collecting pyyaml>=5.1 (from transformers)
#   Using cached pyyaml-6.0.3-cp313-cp313-win_amd64.whl.metadata (2.4 kB)
# Collecting regex!=2019.12.17 (from transformers)
#   Downloading regex-2025.11.3-cp313-cp313-win_amd64.whl.metadata (41 kB)
# Requirement already satisfied: requests in d:\srijan\jupyter-analysis\finance\.venv\lib\site-packages (from transformers) (2.32.5)
# Collecting tokenizers<=0.23.0,>=0.22.0 (from transformers)
#   Using cached tokenizers-0.22.1-cp39-abi3-win_amd64.whl.metadata (6.9 kB)
# Collecting safetensors>=0.4.3 (from transformers)
#   Using cached safetensors-0.7.0-cp38-abi3-win_amd64.whl.metadata (4.2 kB)
# Requirement already satisfied: tqdm>=4.27 in d:\srijan\jupyter-analysis\finance\.venv\lib\site-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in d:\srijan\jupyter-analysis\finance\.venv\lib\site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2025.12.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in d:\srijan\jupyter-analysis\finance\.venv\lib\site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.15.0)
# Requirement already satisfied: pyarrow>=21.0.0 in d:\srijan\jupyter-analysis\finance\.venv\lib\site-packages (from datasets) (22.0.0)
# Collecting dill<0.4.1,>=0.3.0 (from datasets)
#   Using cached dill-0.4.0-py3-none-any.whl.metadata (10 kB)
# Collecting httpx<1.0.0 (from datasets)
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: xxhash in d:\srijan\jupyter-analysis\finance\.venv\lib\site-packages (from datasets) (3.6.0)
# Collecting multiprocess<0.70.19 (from datasets)
#   Using cached multiprocess-0.70.18-py313-none-any.whl.metadata (7.2 kB)
# Collecting fsspec>=2023.5.0 (from huggingface-hub<1.0,>=0.34.0->transformers)
#   Using cached fsspec-2025.10.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in d:\srijan\jupyter-analysis\finance\.venv\lib\site-packages (from fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (3.13.2)
# Collecting anyio (from httpx<1.0.0->datasets)
#   Using cached anyio-4.12.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: certifi in d:\srijan\jupyter-analysis\finance\.venv\lib\site-packages (from httpx<1.0.0->datasets) (2025.11.12)
# Collecting httpcore==1.* (from httpx<1.0.0->datasets)
#   Using cached httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: idna in d:\srijan\jupyter-analysis\finance\.venv\lib\site-packages (from httpx<1.0.0->datasets) (3.11)
# Collecting h11>=0.16 (from httpcore==1.*->httpx<1.0.0->datasets)
#   Using cached h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: sympy>=1.13.3 in d:\srijan\jupyter-analysis\finance\.venv\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in d:\srijan\jupyter-analysis\finance\.venv\lib\site-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in d:\srijan\jupyter-analysis\finance\.venv\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: setuptools in d:\srijan\jupyter-analysis\finance\.venv\lib\site-packages (from torch) (80.9.0)
# Requirement already satisfied: scipy>=1.10.0 in d:\srijan\jupyter-analysis\finance\.venv\lib\site-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.3.0 in d:\srijan\jupyter-analysis\finance\.venv\lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in d:\srijan\jupyter-analysis\finance\.venv\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\srijan\jupyter-analysis\finance\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\srijan\jupyter-analysis\finance\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in d:\srijan\jupyter-analysis\finance\.venv\lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in d:\srijan\jupyter-analysis\finance\.venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in d:\srijan\jupyter-analysis\finance\.venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in d:\srijan\jupyter-analysis\finance\.venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in d:\srijan\jupyter-analysis\finance\.venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in d:\srijan\jupyter-analysis\finance\.venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in d:\srijan\jupyter-analysis\finance\.venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in d:\srijan\jupyter-analysis\finance\.venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets) (1.22.0)
# Requirement already satisfied: six>=1.5 in d:\srijan\jupyter-analysis\finance\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\srijan\jupyter-analysis\finance\.venv\lib\site-packages (from requests->transformers) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\srijan\jupyter-analysis\finance\.venv\lib\site-packages (from requests->transformers) (2.6.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in d:\srijan\jupyter-analysis\finance\.venv\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: colorama in d:\srijan\jupyter-analysis\finance\.venv\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\srijan\jupyter-analysis\finance\.venv\lib\site-packages (from jinja2->torch) (3.0.3)
# Using cached transformers-4.57.3-py3-none-any.whl (12.0 MB)
# Using cached huggingface_hub-0.36.0-py3-none-any.whl (566 kB)
# Using cached tokenizers-0.22.1-cp39-abi3-win_amd64.whl (2.7 MB)
# Using cached datasets-4.4.1-py3-none-any.whl (511 kB)
# Using cached dill-0.4.0-py3-none-any.whl (119 kB)
# Using cached fsspec-2025.10.0-py3-none-any.whl (200 kB)
# Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Using cached httpcore-1.0.9-py3-none-any.whl (78 kB)
# Using cached multiprocess-0.70.18-py313-none-any.whl (151 kB)
# Using cached h11-0.16.0-py3-none-any.whl (37 kB)
# Using cached pyyaml-6.0.3-cp313-cp313-win_amd64.whl (154 kB)
# Downloading regex-2025.11.3-cp313-cp313-win_amd64.whl (277 kB)
# Using cached safetensors-0.7.0-cp38-abi3-win_amd64.whl (341 kB)
# Downloading anyio-4.12.0-py3-none-any.whl (113 kB)
# Installing collected packages: safetensors, regex, pyyaml, h11, fsspec, dill, anyio, multiprocess, huggingface-hub, httpcore, tokenizers, httpx, transformers, datasets
#
#    -- -------------------------------------  1/14 [regex]
#    ----- ----------------------------------  2/14 [pyyaml]
#    ----- ----------------------------------  2/14 [pyyaml]
#    -------- -------------------------------  3/14 [h11]
#   Attempting uninstall: fsspec
#    -------- -------------------------------  3/14 [h11]
#     Found existing installation: fsspec 2025.12.0
#    -------- -------------------------------  3/14 [h11]
#     Uninstalling fsspec-2025.12.0:
#    -------- -------------------------------  3/14 [h11]
#       Successfully uninstalled fsspec-2025.12.0
#    -------- -------------------------------  3/14 [h11]
#    ----------- ----------------------------  4/14 [fsspec]
#    ----------- ----------------------------  4/14 [fsspec]
#    ----------- ----------------------------  4/14 [fsspec]
#    ----------- ----------------------------  4/14 [fsspec]
#    ----------- ----------------------------  4/14 [fsspec]
#    -------------- -------------------------  5/14 [dill]
#    -------------- -------------------------  5/14 [dill]
#    -------------- -------------------------  5/14 [dill]
#    ----------------- ----------------------  6/14 [anyio]
#    ----------------- ----------------------  6/14 [anyio]
#    ----------------- ----------------------  6/14 [anyio]
#    -------------------- -------------------  7/14 [multiprocess]
#    -------------------- -------------------  7/14 [multiprocess]
#    -------------------- -------------------  7/14 [multiprocess]
#    -------------------- -------------------  7/14 [multiprocess]
#    ---------------------- -----------------  8/14 [huggingface-hub]
#    ---------------------- -----------------  8/14 [huggingface-hub]
#    ---------------------- -----------------  8/14 [huggingface-hub]
#    ---------------------- -----------------  8/14 [huggingface-hub]
#    ---------------------- -----------------  8/14 [huggingface-hub]
#    ---------------------- -----------------  8/14 [huggingface-hub]
#    ---------------------- -----------------  8/14 [huggingface-hub]
#    ---------------------- -----------------  8/14 [huggingface-hub]
#    ---------------------- -----------------  8/14 [huggingface-hub]
#    ---------------------- -----------------  8/14 [huggingface-hub]
#    ---------------------- -----------------  8/14 [huggingface-hub]
#    ---------------------- -----------------  8/14 [huggingface-hub]
#    ---------------------- -----------------  8/14 [huggingface-hub]
#    ---------------------- -----------------  8/14 [huggingface-hub]
#    ---------------------- -----------------  8/14 [huggingface-hub]
#    ---------------------- -----------------  8/14 [huggingface-hub]
#    ------------------------- --------------  9/14 [httpcore]
#    ------------------------- --------------  9/14 [httpcore]
#    ------------------------- --------------  9/14 [httpcore]
#    ---------------------------- ----------- 10/14 [tokenizers]
#    ---------------------------- ----------- 10/14 [tokenizers]
#    ------------------------------- -------- 11/14 [httpx]
#    ------------------------------- -------- 11/14 [httpx]
#    ------------------------------- -------- 11/14 [httpx]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ---------------------------------- ----- 12/14 [transformers]
#    ------------------------------------- -- 13/14 [datasets]
#    ------------------------------------- -- 13/14 [datasets]
#    ------------------------------------- -- 13/14 [datasets]
#    ------------------------------------- -- 13/14 [datasets]
#    ------------------------------------- -- 13/14 [datasets]
#    ------------------------------------- -- 13/14 [datasets]
#    ------------------------------------- -- 13/14 [datasets]
#    ------------------------------------- -- 13/14 [datasets]
#    ------------------------------------- -- 13/14 [datasets]
#    ------------------------------------- -- 13/14 [datasets]
#    ------------------------------------- -- 13/14 [datasets]
#    ------------------------------------- -- 13/14 [datasets]
#    ------------------------------------- -- 13/14 [datasets]
#    ------------------------------------- -- 13/14 [datasets]
#    ---------------------------------------- 14/14 [datasets]
#
# Successfully installed anyio-4.12.0 datasets-4.4.1 dill-0.4.0 fsspec-2025.10.0 h11-0.16.0 httpcore-1.0.9 httpx-0.28.1 huggingface-hub-0.36.0 multiprocess-0.70.18 pyyaml-6.0.3 regex-2025.11.3 safetensors-0.7.0 tokenizers-0.22.1 transformers-4.57.3
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# Load your specific file
df = pd.read_csv('../archive (3)/analyst_ratings_processed.csv')

print(f"✅ Loaded {len(df)} rows.")
print("\nFirst 3 rows:")
print(df.head(3))

print("\nColumn Names:")
print(list(df.columns))

# Assuming there is a column like 'stock_rating' or 'value', let's check the unique labels
# (Update 'stock_rating' below if the print above shows a different name)
if 'stock_rating' in df.columns:
    print("\nUnique Ratings found:")
    print(df['stock_rating'].value_counts().head(10))
# Out:
# ✅ Loaded 1400469 rows.
#
# First 3 rows:
#    Unnamed: 0                                       title  \
# 0         0.0     Stocks That Hit 52-Week Highs On Friday
# 1         1.0  Stocks That Hit 52-Week Highs On Wednesday
# 2         2.0               71 Biggest Movers From Friday
#
#                         date stock
# 0  2020-06-05 10:30:00-04:00     A
# 1  2020-06-03 10:45:00-04:00     A
# 2  2020-05-26 04:30:00-04:00     A
#
# Column Names:
# ['Unnamed: 0', 'title', 'date', 'stock']

# %%
import torch
import pandas as pd
import plotly.express as px
from transformers import BertTokenizer, BertForSequenceClassification
from tqdm import tqdm

# 1. Setup Device (GPU is much faster)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

# 2. Load the Pre-Trained FinBERT (The Expert)
tokenizer = BertTokenizer.from_pretrained('ProsusAI/finbert')
model = BertForSequenceClassification.from_pretrained('ProsusAI/finbert').to(device)
model.eval()

# 3. Filter Data for a Specific Stock (e.g., AAPL)
# The dataset uses tickers. Let's grab Apple.
target_stock = 'AAPL'
df_stock = df[df['stock'] == target_stock].head(100).copy() # Limit to 100 for speed demo

print(f"Analyzing {len(df_stock)} headlines for {target_stock}...")

# 4. The Inference Loop (Reading the News)
predictions = []
confidence_scores = []

for title in tqdm(df_stock['title']):
    # Tokenize
    inputs = tokenizer(title, return_tensors="pt", truncation=True, padding=True, max_length=64).to(device)
    
    # Predict
    with torch.no_grad():
        outputs = model(**inputs)
        probs = torch.nn.functional.softmax(outputs.logits, dim=-1)
    
    # Logic: Class 0=Positive, 1=Negative, 2=Neutral (Check config usually)
    # FinBERT 'ProsusAI' Output: [Positive, Negative, Neutral]
    # We will create a "Sentiment Score": Positive Prob - Negative Prob
    # Score > 0 = Bullish, Score < 0 = Bearish
    
    # ProsusAI mapping: 0=Positive, 1=Negative, 2=Neutral
    score = probs[0][0].item() - probs[0][1].item() # Positive - Negative
    predictions.append(score)

df_stock['sentiment_score'] = predictions

# 5. Visualize the "Alpha Signal"
fig = px.bar(df_stock, x='date', y='sentiment_score',
             color='sentiment_score',
             color_continuous_scale=['red', 'gray', 'green'],
             hover_data=['title'],
             title=f'AI-Generated Sentiment Signal for {target_stock} (FinBERT)')
fig.show()
# Out:
# Using device: cpu
# d:\Srijan\Jupyter-Analysis\Finance\.venv\Lib\site-packages\huggingface_hub\file_download.py:143: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\Admin49\.cache\huggingface\hub\models--ProsusAI--finbert. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# Analyzing 100 headlines for AAPL...
#  75%|███████▌  | 75/100 [00:01<00:00, 52.50it/s]Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# 100%|██████████| 100/100 [00:01<00:00, 51.08it/s]

# %%
# Quick Sanity Check: Print the raw logic
print(f"Checking first 5 headlines for {target_stock}...\n")

for i, row in df_stock.head(5).iterrows():
    title = row['title']
    score = row['sentiment_score']
    
    # Interpret the score
    if score > 0.1: sentiment = "🟢 BULLISH"
    elif score < -0.1: sentiment = "🔴 BEARISH"
    else: sentiment = "⚪ NEUTRAL"
    
    print(f"📰 {title}")
    print(f"   ↳ {sentiment} (Score: {score:.4f})\n")
# Out:
# Checking first 5 headlines for AAPL...
#
# 📰 Tech Stocks And FAANGS Strong Again To Start Day As Market Awaits Fed
#    ↳ 🟢 BULLISH (Score: 0.8182)
#
# 📰 10 Biggest Price Target Changes For Wednesday
#    ↳ 🔴 BEARISH (Score: -0.1148)
#
# 📰 Benzinga Pro's Top 5 Stocks To Watch For Wed., Jun. 10, 2020: AAPL, BAC, NIO, SONO, GLW
#    ↳ ⚪ NEUTRAL (Score: 0.0361)
#
# 📰 Deutsche Bank Maintains Buy on Apple, Raises Price Target to $350
#    ↳ 🟢 BULLISH (Score: 0.7173)
#
# 📰 Apple To Let Users Trade In Their Mac Computers For Credit At US, Canada Stores: Report
#    ↳ ⚪ NEUTRAL (Score: 0.0229)

# %%
# Save the analyzed data
df_stock.to_csv('aapl_sentiment_analysis.csv', index=False)
print("✅ Saved analysis to aapl_sentiment_analysis.csv")
# Out:
# ✅ Saved analysis to aapl_sentiment_analysis.csv
